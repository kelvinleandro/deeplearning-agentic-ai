# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a helpful writing assistant. Write a complete, well-structured essay draft on the following topic:

    Topic: {topic}

    The essay should include:
    - A clear introduction with a thesis statement
    - 2–3 body paragraphs with supporting arguments and examples
    - A conclusion that summarizes the main points

    Make sure the essay is coherent and formal.
    """

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert writing coach. Read the following essay draft and provide constructive, detailed feedback.

    Essay Draft:
    {draft}

    Please comment on:
    - Clarity and coherence of ideas
    - Organization and structure
    - Strength of arguments and evidence
    - Grammar, tone, and style
    - Suggestions for improvement

    Provide your feedback in a well-organized paragraph format.
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert editor. Below is an essay draft followed by feedback about it.

    Essay Draft:
    {original_draft}

    Feedback:
    {reflection}

    Using the feedback, revise the essay to improve its clarity, coherence, argument strength, and overall flow.
    Address all major points in the feedback and enhance grammar, tone, and style as needed.

    Return only the final, revised essay text.
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become integral components of daily life, allowing billions worldwide to connect, share information, and express themselves freely. However, this unprecedented digital expansion has also raised critical issues, including privacy threats, misinformation, and the potential for societal harm. Consequently, a debate has emerged regarding whether the government should regulate social media platforms to ensure they operate in a way that aligns with societal interests. This essay argues that government regulation of social media is necessary to protect user privacy, prevent the spread of harmful content, and ensure the platforms contribute positively to societal well-being.
#
# Body Paragraph 1: Protecting User Privacy
#
# One of the foremost reasons for the government to regulate social media platforms is to safeguard user privacy. Social media companies collect vast amounts of personal data from their users, often without explicit consent or clear understanding from the users themselves. This data is frequently utilized for targeted advertising, creating a risk of data misuse or breaches. Government regulation could involve enforcing transparent data collection practices, implementing stricter consent requirements, and ensuring robust data protection measures. Such regulation would not only protect individual privacy rights but also foster consumer trust, which is essential for the sustainable growth of these platforms.
#
# Body Paragraph 2: Combating Misinformation and Harmful Content
#
# Another critical reason for government intervention is the rampant spread of misinformation and harmful content on these platforms. The algorithms designed to maximize user engagement often inadvertently promote sensationalist and misleading information, exacerbating the spread of fake news and creating echo chambers. This can have dire consequences, such as influencing public opinion based on falsehoods or inciting violence. A regulatory framework could mandate social media platforms to develop more responsible content algorithms, establish clearer guidelines for content moderation, and enforce penalties for non-compliance. Such measures would be instrumental in mitigating the spread of harmful content and fostering a more informed and rational public discourse.
#
# Body Paragraph 3: Promoting Societal Well-being
#
# Finally, government regulation is necessary to ensure that social media platforms contribute positively to societal well-being rather than detract from it. Without oversight, these platforms prioritize profit over the public interest, often neglecting the societal impact of their operations. For example, excessive social media usage has been linked to mental health issues, particularly among young users. Government regulations could incentivize platforms to design features that encourage healthier usage patterns and actively promote educational and socially beneficial content. By emphasizing the welfare of society in regulatory frameworks, governments can guide social media platforms to become more responsible corporate citizens.
#
# Conclusion
#
# In conclusion, while social media platforms have revolutionized communication and information sharing, they also pose significant risks that necessitate government regulation. Such regulation would protect user privacy, prevent the dissemination of harmful content, and promote the platforms' contribution to societal well-being. As social media continues to evolve, it is imperative for government entities to develop and implement comprehensive regulatory measures, ensuring that these digital spheres serve the interests of individuals and society at large, rather than merely the bottom line of corporate enterprises.
#
# 🧠 Feedback:
#
# Overall, your essay presents a clear and focused thesis: that government regulation of social media platforms is necessary to protect privacy, curb harmful content, and promote societal well-being. Your introduction effectively sets up the stakes, and each body paragraph targets one of your main points. The progression from privacy to misinformation to mental-health considerations feels logical, and your conclusion neatly ties these threads back to your central claim. Readers should have little trouble following your line of reasoning.
#
# In terms of organization, your essay follows a classic five-paragraph structure, which provides a solid backbone for your argument. Each body paragraph begins with a topic sentence that signals its purpose, and you maintain internal coherence by sticking closely to each sub-topic. However, transitions between paragraphs could be strengthened—for example, by explicitly linking how privacy concerns feed into broader questions of trust and platform accountability as you shift to misinformation. Likewise, you might consider a brief roadmap sentence at the end of your introduction so readers know exactly what to expect in each section.
#
# While your claims are persuasive, they would gain credibility from more concrete evidence. Right now you assert that “social media companies collect vast amounts of personal data” and that “algorithms … inadvertently promote sensationalist information,” but you don’t cite examples or data. Incorporating a statistic on data-breach incidents, a high-profile case of disinformation (e.g., election-related fake news), or peer-reviewed studies on social-media–linked mental-health outcomes would deepen your analysis and preempt critics who ask “How do we know this is really happening?” You could also address counterarguments—such as claims that self-regulation or user education is sufficient—to show you’ve considered alternative viewpoints before reaffirming the necessity of government intervention.
#
# Your grammar, tone, and style are appropriately formal and consistent; you avoid colloquialisms and you rarely have distracting errors. To elevate the style further, watch out for repetition of key phrases (“government regulation,” “social media platforms”). Vary your language by using synonyms—e.g., “public-interest safeguards,” “digital networks,” or “platform oversight.” You might also intersperse more dynamic sentences (short, punchy statements) amidst your longer, complex constructions to maintain reader engagement.
#
# Finally, for revision:
# 1) Introduce specific examples or data points to back up each claim.
# 2) Add smoother transitions and consider a thesis-roadmap at the end of your introduction.
# 3) Briefly acknowledge and rebut at least one major counterargument.
# 4) Vary your diction to avoid repetitive phrasing.
# 5) If space allows, expand your conclusion to offer a call to action or reflect on potential challenges in implementing regulation. By weaving in these enhancements, you will strengthen both the persuasiveness and polish of your essay.
#
# ✍️ Revised:
#
# Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become essential components of everyday life, facilitating global connections, information sharing, and self-expression. However, this rapid digital expansion has introduced critical challenges, including privacy breaches, misinformation proliferation, and potential societal harm. Consequently, a debate has emerged on whether government intervention is necessary to ensure these platforms operate in alignment with public interest. This essay argues that government regulation is crucial to safeguard user privacy, curb the spread of harmful content, and promote societal well-being. The ensuing discourse will explore each of these facets, highlighting the urgent need for regulatory measures.
#
# Body Paragraph 1: Protecting User Privacy
#
# A primary reason for government oversight of digital networks is to safeguard user privacy. Social media companies often collect vast amounts of personal data without explicit user consent or a clear understanding of its implications. For instance, recent high-profile data breaches have exposed the vulnerabilities in the way these platforms handle sensitive information. Regulation could enforce transparent data collection practices, mandate stricter consent requirements, and ensure robust data protection measures. Such public-interest safeguards would protect individual privacy rights and foster consumer trust, which is vital for the sustainable growth of these platforms.
#
# Body Paragraph 2: Combating Misinformation and Harmful Content
#
# Additionally, government intervention is essential to address the rampant spread of misinformation and harmful content on these digital spaces. Algorithms designed to maximize user engagement often prioritize sensationalist and misleading content, inadvertently promoting disinformation. A regulatory framework could require platforms to develop responsible content algorithms, establish clearer moderation guidelines, and impose penalties for non-compliance. For example, the dissemination of election-related fake news demonstrates the potential consequences of unchecked misinformation. By implementing platform oversight, governments can mitigate harmful content dissemination and foster more informed public discourse.
#
# Body Paragraph 3: Promoting Societal Well-being
#
# Furthermore, regulation is necessary to ensure social media platforms contribute positively to societal well-being. Without oversight, these platforms may prioritize profits over public interest, neglecting their societal impact. For example, excessive social media usage is linked to mental health issues among young users. Government regulations could incentivize platforms to design features that encourage healthier usage patterns and actively promote educational content. By emphasizing societal welfare in regulatory frameworks, governments can guide these platforms to become responsible corporate citizens.
#
# Conclusion
#
# In conclusion, while social media platforms have revolutionized communication, they pose significant risks that necessitate government regulation. Such regulation would protect user privacy, prevent the spread of harmful content, and promote societal well-being. Although some argue for self-regulation or user education, these alone are insufficient to address the profound challenges discussed. As digital networks continue to evolve, it is imperative for governments to implement comprehensive regulatory measures. By doing so, these platforms can serve the interests of individuals and society at large, rather than merely prioritizing corporate profits. As challenges in implementing regulation arise, it is crucial for stakeholders to collaborate, ensuring these digital landscapes contribute positively to our world.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become integral components of daily life, allowing billions worldwide to connect, share information, and express themselves freely. However, this unprecedented digital expansion has also raised critical issues, including privacy threats, misinformation, and the potential for societal harm. Consequently, a debate has emerged regarding whether the government should regulate social media platforms to ensure they operate in a way that aligns with societal interests. This essay argues that government regulation of social media is necessary to protect user privacy, prevent the spread of harmful content, and ensure the platforms contribute positively to societal well-being.
#
# Body Paragraph 1: Protecting User Privacy
#
# One of the foremost reasons for the government to regulate social media platforms is to safeguard user privacy. Social media companies collect vast amounts of personal data from their users, often without explicit consent or clear understanding from the users themselves. This data is frequently utilized for targeted advertising, creating a risk of data misuse or breaches. Government regulation could involve enforcing transparent data collection practices, implementing stricter consent requirements, and ensuring robust data protection measures. Such regulation would not only protect individual privacy rights but also foster consumer trust, which is essential for the sustainable growth of these platforms.
#
# Body Paragraph 2: Combating Misinformation and Harmful Content
#
# Another critical reason for government intervention is the rampant spread of misinformation and harmful content on these platforms. The algorithms designed to maximize user engagement often inadvertently promote sensationalist and misleading information, exacerbating the spread of fake news and creating echo chambers. This can have dire consequences, such as influencing public opinion based on falsehoods or inciting violence. A regulatory framework could mandate social media platforms to develop more responsible content algorithms, establish clearer guidelines for content moderation, and enforce penalties for non-compliance. Such measures would be instrumental in mitigating the spread of harmful content and fostering a more informed and rational public discourse.
#
# Body Paragraph 3: Promoting Societal Well-being
#
# Finally, government regulation is necessary to ensure that social media platforms contribute positively to societal well-being rather than detract from it. Without oversight, these platforms prioritize profit over the public interest, often neglecting the societal impact of their operations. For example, excessive social media usage has been linked to mental health issues, particularly among young users. Government regulations could incentivize platforms to design features that encourage healthier usage patterns and actively promote educational and socially beneficial content. By emphasizing the welfare of society in regulatory frameworks, governments can guide social media platforms to become more responsible corporate citizens.
#
# Conclusion
#
# In conclusion, while social media platforms have revolutionized communication and information sharing, they also pose significant risks that necessitate government regulation. Such regulation would protect user privacy, prevent the dissemination of harmful content, and promote the platforms' contribution to societal well-being. As social media continues to evolve, it is imperative for government entities to develop and implement comprehensive regulatory measures, ensuring that these digital spheres serve the interests of individuals and society at large, rather than merely the bottom line of corporate enterprises.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Overall, your essay presents a clear and focused thesis: that government regulation of social media platforms is necessary to protect privacy, curb harmful content, and promote societal well-being. Your introduction effectively sets up the stakes, and each body paragraph targets one of your main points. The progression from privacy to misinformation to mental-health considerations feels logical, and your conclusion neatly ties these threads back to your central claim. Readers should have little trouble following your line of reasoning.
#
# In terms of organization, your essay follows a classic five-paragraph structure, which provides a solid backbone for your argument. Each body paragraph begins with a topic sentence that signals its purpose, and you maintain internal coherence by sticking closely to each sub-topic. However, transitions between paragraphs could be strengthened—for example, by explicitly linking how privacy concerns feed into broader questions of trust and platform accountability as you shift to misinformation. Likewise, you might consider a brief roadmap sentence at the end of your introduction so readers know exactly what to expect in each section.
#
# While your claims are persuasive, they would gain credibility from more concrete evidence. Right now you assert that “social media companies collect vast amounts of personal data” and that “algorithms … inadvertently promote sensationalist information,” but you don’t cite examples or data. Incorporating a statistic on data-breach incidents, a high-profile case of disinformation (e.g., election-related fake news), or peer-reviewed studies on social-media–linked mental-health outcomes would deepen your analysis and preempt critics who ask “How do we know this is really happening?” You could also address counterarguments—such as claims that self-regulation or user education is sufficient—to show you’ve considered alternative viewpoints before reaffirming the necessity of government intervention.
#
# Your grammar, tone, and style are appropriately formal and consistent; you avoid colloquialisms and you rarely have distracting errors. To elevate the style further, watch out for repetition of key phrases (“government regulation,” “social media platforms”). Vary your language by using synonyms—e.g., “public-interest safeguards,” “digital networks,” or “platform oversight.” You might also intersperse more dynamic sentences (short, punchy statements) amidst your longer, complex constructions to maintain reader engagement.
#
# Finally, for revision:
# 1) Introduce specific examples or data points to back up each claim.
# 2) Add smoother transitions and consider a thesis-roadmap at the end of your introduction.
# 3) Briefly acknowledge and rebut at least one major counterargument.
# 4) Vary your diction to avoid repetitive phrasing.
# 5) If space allows, expand your conclusion to offer a call to action or reflect on potential challenges in implementing regulation. By weaving in these enhancements, you will strengthen both the persuasiveness and polish of your essay.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Necessity of Government Regulation on Social Media Platforms
#
# Introduction
#
# In the digital age, social media platforms have become essential components of everyday life, facilitating global connections, information sharing, and self-expression. However, this rapid digital expansion has introduced critical challenges, including privacy breaches, misinformation proliferation, and potential societal harm. Consequently, a debate has emerged on whether government intervention is necessary to ensure these platforms operate in alignment with public interest. This essay argues that government regulation is crucial to safeguard user privacy, curb the spread of harmful content, and promote societal well-being. The ensuing discourse will explore each of these facets, highlighting the urgent need for regulatory measures.
#
# Body Paragraph 1: Protecting User Privacy
#
# A primary reason for government oversight of digital networks is to safeguard user privacy. Social media companies often collect vast amounts of personal data without explicit user consent or a clear understanding of its implications. For instance, recent high-profile data breaches have exposed the vulnerabilities in the way these platforms handle sensitive information. Regulation could enforce transparent data collection practices, mandate stricter consent requirements, and ensure robust data protection measures. Such public-interest safeguards would protect individual privacy rights and foster consumer trust, which is vital for the sustainable growth of these platforms.
#
# Body Paragraph 2: Combating Misinformation and Harmful Content
#
# Additionally, government intervention is essential to address the rampant spread of misinformation and harmful content on these digital spaces. Algorithms designed to maximize user engagement often prioritize sensationalist and misleading content, inadvertently promoting disinformation. A regulatory framework could require platforms to develop responsible content algorithms, establish clearer moderation guidelines, and impose penalties for non-compliance. For example, the dissemination of election-related fake news demonstrates the potential consequences of unchecked misinformation. By implementing platform oversight, governments can mitigate harmful content dissemination and foster more informed public discourse.
#
# Body Paragraph 3: Promoting Societal Well-being
#
# Furthermore, regulation is necessary to ensure social media platforms contribute positively to societal well-being. Without oversight, these platforms may prioritize profits over public interest, neglecting their societal impact. For example, excessive social media usage is linked to mental health issues among young users. Government regulations could incentivize platforms to design features that encourage healthier usage patterns and actively promote educational content. By emphasizing societal welfare in regulatory frameworks, governments can guide these platforms to become responsible corporate citizens.
#
# Conclusion
#
# In conclusion, while social media platforms have revolutionized communication, they pose significant risks that necessitate government regulation. Such regulation would protect user privacy, prevent the spread of harmful content, and promote societal well-being. Although some argue for self-regulation or user education, these alone are insufficient to address the profound challenges discussed. As digital networks continue to evolve, it is imperative for governments to implement comprehensive regulatory measures. By doing so, these platforms can serve the interests of individuals and society at large, rather than merely prioritizing corporate profits. As challenges in implementing regulation arise, it is crucial for stakeholders to collaborate, ensuring these digital landscapes contribute positively to our world.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
